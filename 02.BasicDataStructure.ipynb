# %% [markdown]
# # 02 基本的データ構造: Basic Data Structures
# - [リスト: Lists](#リスト:-Lists)
# - [集合: Sets](#集合:-Sets)
# - [辞書: Dictionaries](#辞書:-Dictionaries)
# - [タプル: Tuples](#タプル:-Tuples)
#     - [名前付きタプル: Named Tuples](#名前付きタプル:-Named-Tuples)
#
# ----

# %% [markdown]
# ## コンテナ型: Container Types
#
# 多くのアプリケーションでは、データの集合を扱うことが不可欠である。
# コンテナ型は、複数のアイテムを単一の変数に格納し、操作できるデータ構造である。
# Pythonは、リスト、タプル、辞書、セットなどの組み込みコンテナ型がある。
# これらは、複数のアイテムを単一の変数に格納し、操作できる。
#
# For many applications, it is essential to handle collections of data.
# Container types are data structures that allow you to store and manipulate multiple items in a single variable.
# Python provides several built-in container types, such as lists, tuples, dictionaries, and sets.
# These allow you to store and manipulate multiple items in a single variable.
#
# ----

# %% [markdown]
# ## リスト: Lists
#
# リストは、順序付けられた可変長(要素の数が変わる)の要素のコレクションである。
# リストの生成には、角括弧 `[]` を使用し、要素はコンマで区切る。
# なお、Pythonのリストは、異なるデータ型のアイテムを含むことができる。
# - 要素には0から番号(インデックス)が付けられ、番号でアクセスできる。
# - 最後の要素は、インデックス-1でアクセスできる。
# - `:` を使用して、リストのスライス(部分)を取得できる。
# - リストは、要素の追加、削除、変更が可能である。
#
#
# Lists are ordered, mutable (changeable) collections of elements.
# You can create a list using square brackets `[]`, with elements separated by commas.
# Note that Python lists can contain items of different data types.
# - Elements are numbered with an index, starting at 0, and can be accessed by their index.
# - The last element can be accessed with index -1.
# - You can use `:` to get a slice (part) of the list.
# - Lists can be modified by adding, removing, or changing elements.

# %%
d = [3, 1, 4, 1, 5, 9] # リストの作成: Creating a list
print(d)               # リストの表示: Displaying the list
print(d[0])            # インデックスを使用して要素にアクセス: Accessing an element using an index
print(d[-1])           # 負のインデックスを使用して要素にアクセス: Accessing an element using a negative index
print(d[2:5])         # スライスを使用して部分リストにアクセス: Accessing a sublist using slicing
d.append(2)          # 要素の追加: Adding an element
print(d)               # 変更後のリストの表示: Displaying the modified list
del d[0]              # 要素の削除: Removing an element
print(d)               # 変更後のリストの表示: Displaying the modified list

# %% [markdown]
# 空 (要素数が0) のリストは、次のように作成する。
# An empty (0 elements) list can be created as follows:
# ```python
# empty_list = []
# empty_list = list()
# ```
# ----

# %% [markdown]
# リストの一つ一つの要素に対する操作は、`for`文を使って行う。複数の方法がある。
# 1. `len()`関数を使ってリストの長さを取得し、インデックスを用いて要素にアクセスする方法
# 2. 直接`for`文でリストの要素を反復処理する方法
# 3. `enumerate()`関数を使ってインデックスと要素の両方にアクセスする方法
#
# ----
#
# Operations on individual elements of a list can be performed using `for` loops. There are several methods to do this.
# 1. Using the `len()` function to get the length of the list and accessing elements via their indices.
# 2. Iterating directly over the elements of the list using a `for` loop.
# 3. Using the `enumerate()` function to access both indices and elements.

# %%
d = [3, 1, 4, 1, 5, 9]
n = len(d)            # リストの長さを取得: Getting the length of the list
s = 0
for i in range(n):    # リストの要素を順に処理: Iterating through the list
    s += d[i]         # 要素の合計を計算: Calculating the sum of elements
print("Sum:", s)      # 合計の表示: Displaying the sum

s = 0
for x in d:          # リストの要素を順に処理: Iterating through the list
    s += x * x       # 要素の二乗の合計を計算: Calculating the sum of squares of elements
print("Sum of squares:", s) # 二乗の合計の表示: Displaying the sum of squares

s = 0
for i, x in enumerate(d): # インデックスと要素を同時に取得: Getting index and element simultaneously
    s += i * x         # インデックスと要素の積の合計を計算: Calculating the sum of index-element products
print("Sum of index-element products:", s) # 積の合計の表示: Displaying the sum of index-element products

# %% [markdown]
# #### 課題
# 上記のリスト`d`に対して、各要素を2倍した新しいリスト`d2`を作成するコードを書き、動作を確認せよ。
#
# Write code to create a new list `d2` where each element of the list `d` is doubled.

# %% [markdown]
# ## 集合: Sets
# 集合は、順序付けられておらず、重複しない、つまり同じ要素が複数存在しない要素のコレクションである。
# 集合は、中括弧 `{}` を使用して生成する。
# 要素にはインデクスが無いため、リストのようにインデクスを使用してアクセスすることはできない。
# 集合は、要素の追加や削除が可能である。
# - `add()` メソッドを使用して要素を追加できる。
# - `remove()` メソッドを使用して要素を削除できる。
#
# Sets are unordered collections of unique elements, meaning that the same element cannot appear more than once.
# Sets are created using curly braces `{}`.
# Since sets do not have indices, you cannot access elements using an index like you can with lists.
# Sets can be modified by adding or removing elements.
# - You can add elements using the `add()` method.
# - You can remove elements using the `remove()` method.

# %%
s = {'apple', 'banana', 'cherry'}
print(s)
s.add('orange')
print(s)
s.remove('banana')
print(s)

for fruit in s:# 集合の要素を順に処理: Iterating through the set
    print(fruit)

# %% [markdown]
# 空の集合は、次のように作成する。
# An empty set can be created as follows:
# ```python
# empty_set = {}
# empty_set = set()
# ```
# ----

# %% [markdown]
# ## 辞書: Dictionaries
# 辞書は、キーと値のペアのコレクションであり、キーは一意でなければならない。辞書は、中括弧 `{}` を使用して生成し、各キーと値のペアはコロン `:` で区切られ、ペア同士はコンマで区切られる。
# - `keys()` メソッドを使用して、辞書のキーを表示できる。
# - `values()` メソッドを使用して、辞書の値を表示できる。
#
# Dictionaries are collections of key-value pairs, where keys must be unique. Dictionaries are created using curly braces `{}`, with each key-value pair separated by a colon `:`, and pairs separated by commas.
# - `keys()` method to display the keys of a dictionary.
# - `values()` method to display the values of a dictionary.

# %%
colors = {'red': '#FF0000', 'green': '#00FF00', 'blue': '#0000FF', 'cyan': '#00FFFF', 'purple': '#FF00FF'}
print(colors)
colors['yellow'] = '#FFFF00' # 新しいキーと値の追加: Adding a new key-value pair
for color, hex_code in colors.items(): # キーと値を同時に取得: Getting keys and values simultaneously
    print(f"{color}: {hex_code}")
print(colors.keys()) # キーの表示: Displaying keys
print(colors.values()) # 値の表示: Displaying values

# %% [markdown]
# 空の辞書は、次のように作成する。
# An empty dictionary can be created as follows:
# ```python
# empty_dict = {}
# empty_dict = dict()
# ```
# ----

# %% [markdown]
# ### 課題: Exercise
# 上記の辞書`colors`に対して、キー`orange`、値`#FFA500`を追加しなさい。追加には、`colors['キー'] = 値`の形式を使用すること。
# また、追加されたことを確認しなさい。
#
# Add the key `orange` with the value `#FFA500` to the dictionary `colors` using the format `colors['key'] = value`.
# Also, verify that the key has been added.

# %% [markdown]
# ## タプル: Tuples
# タプルは、順序付けられた不変(要素が変わらない)の要素のコレクションであり、異なるデータ型の要素を含むことができる。
# タプルの生成には、丸括弧 `()` を使用し、要素はコンマで区切る。
# 後述する、関数から複数の値を返す場合などに便利である。要素の変更はできない (イミュータブル)。
# また、括弧は省略可能である。
#
# Tuples are ordered, immutable (unchangeable) collections of elements that can contain items of different data types.
# Tuples are created using parentheses `()`, with elements separated by commas.
# They are useful for returning multiple values from functions, among other things.
# Elements cannot be changed (immutable).
# Parentheses are optional.

# %%
t = (3, 'apple', 4.5) # タプルの作成: Creating a tuple
print(t)                     # タプルの表示: Displaying the tuple
try:
    t[0] = 5                  # エラー: タプルは不変
except TypeError as e:
    print("Error:", e)        # エラーメッセージの表示: Displaying the error message

t = t + (6,)  # タプルへの要素の追加: Adding an element to the tuple
print(t)  # 変更後のタプルの表示: Displaying the modified tuple

t1,t2,t3, t4 = t  # タプルの分解: Unpacking the tuple
print(t1, t2, t3, t4) # 分解した要素

# %% [markdown]
# ## 名前付きタプル: Named Tuples
# タプルに要素の名前を付けたものであり、コードの可読性と自己文書化を向上させる。
# 名前付きタプルは、標準のタプルに名前付きフィールドを追加したものであり、コードの可読性と自己文書化を向上させる。
#
# The tuples with named elements improve code readability and self-documentation.
# Named tuples are an extension of standard tuples that add named fields, improving code readability and self-documentation.

# %%
from typing import NamedTuple
class Point(NamedTuple):
    x: int
    y: int

p = Point(10, 20)
print(p)
print("x:", p.x, "y:", p.y)
