# %% [markdown]
# # 02 基本的データ構造: Basic Data Structures

# %% [markdown]
# ## 課題
#
# リスト`[3, 1, 5, 2, 4, 8]`に対して、`for`文を用いて、最小の要素に対するインデックスを求めるプログラムを作成し、動作を確認しなさい。
#
# Create a program that uses a `for` loop to find the index of the smallest element in the list `[3, 1, 5, 2, 4, 8]`. Verify its operation.

# %% [markdown]
# ## 演習問題: Exercise
# リスト`[3, 1, 5, 2, 4, 8]`に対して、`for`文を用いて、各要素の二乗を計算し、新しいリストに格納するプログラムを作成し、動作を確認しなさい。
#
# Create a program that uses a `for` loop to calculate the square of each element in the list `[3, 1, 5, 2, 4, 8]` and stores it in a new list. Verify its operation.

# %% [markdown]
# ## 演習問題: Exercise
# 以下のソースコードは、$[a, b]$の範囲ででたらめに$n$個の整数を生成するプログラムである。当然、生成される整数は重複する可能性がある。そこで、`set`を用いて、重複を排除した整数の集合を作成するプログラムを作成し、動作を確認しなさい。
# なお、下のコードは、リスト内包表記を用いて、$n$個の整数を生成している。
#
# The following source code is a program that generates $n$ random integers in the range $[a, b]$. Naturally, the generated integers may be duplicated. Therefore, create a program that uses a `set` to create a collection of unique integers and verify its operation.
# The code below uses list comprehension to generate $n$ integers.
#
# ```python
# import random
# a = 1
# b = 10
# n = 20
# random_integers = [random.randint(a, b) for _ in range(n)]

# %% [markdown]
# ## 演習問題: Exercise
# `0`と`1`がデタラメにならんだ長さ`n`のリストを生成するプログラムを作成し、`dict`を用いて、`0`と`1`の出現回数を数えるプログラムを作成し、動作を確認しなさい。
#
# Create a program that generates a list of length `n` with random `0`s and `1`s, and then uses a `dict` to count the occurrences of `0`s and `1`s. Verify its operation.
