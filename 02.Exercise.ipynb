# %% [markdown]
# # 02 基本的データ構造: Basic Data Structures

# %%
# 学籍番号: 
# 氏名:

# %% [markdown]
# ## 課題
#
# リスト`[3, 1, 5, 2, 4, 8]`に対して、`for`文を用いて、最小の要素のあるインデックスを求めるプログラムを作成しなさい。
#
# Create a program that uses a `for` loop to find the index of the smallest element in the list `[3, 1, 5, 2, 4, 8]`.
